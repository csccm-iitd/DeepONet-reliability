# %%
# %reset -f

# import numpy as np
# import scipy.io as sp
# import tensorflow as tf
# import matplotlib.pyplot as plt

# from tensorflow import keras
# from keras.models import Model
# from keras.layers.merge import concatenate
# from tensorflow.keras import initializers, regularizers
# from tensorflow.keras.layers import Dense, Input, Lambda, Dot
# from tensorflow.keras.layers.experimental import preprocessing


# dt = 0.01
# min_t = 0
# max_t = 2

# t = np.arange(min_t, max_t, dt)
# lt = t.shape[0]

# samples = 1500

# def rkm(y1, y2, y3, y4, y5, y6, y7, y8, y9, y10, f, t):
#     h = dt
    
#     F1 = lambda Y: Y[6]
#     F2 = lambda Y: Y[7]
#     F3 = lambda Y: Y[8]
#     F4 = lambda Y: Y[9]
#     F5 = lambda Y: Y[10]
#     F6 = lambda Y: (1/M1)*(-M1*f-(C1*Y[5+1]+K1*Y[1]+C2*(Y[5+1]-Y[5+2])+K2*(Y[1]-Y[2])+alpha*Y[1]**3))
#     F7 = lambda Y: (1/M2)*(-M2*f-(C2*(Y[5+2]-Y[5+1])+K2*(Y[2]-Y[1])+C3*(Y[5+2]-Y[5+3])+K3*(Y[2]-Y[3])))
#     F8 = lambda Y: (1/M3)*(-M3*f-(C3*(Y[5+3]-Y[5+2])+K3*(Y[3]-Y[2])+C4*(Y[5+3]-Y[5+4])+K5*(Y[3]-Y[4])))
#     F9 = lambda Y: (1/M4)*(-M4*f-(C4*(Y[5+4]-Y[5+3])+K4*(Y[4]-Y[3])+C5*(Y[5+4]-Y[5+5])+K5*(Y[4]-Y[5])))
#     F10 = lambda Y: (1/M5)*(-M5*f-(C5*(Y[5+5]-Y[5+4])+K5*(Y[5]-Y[4])))


#     k0 = h*F1([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#     l0 = h*F2([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#     m0 = h*F3([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#     n0 = h*F4([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#     o0 = h*F5([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#     p0 = h*F6([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#     q0 = h*F7([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#     r0 = h*F8([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#     s0 = h*F9([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#     t0 = h*F10([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);

#     k1 = h*F1([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#     l1 = h*F2([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#     m1 = h*F3([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#     n1 = h*F4([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#     o1 = h*F5([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#     p1 = h*F6([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#     q1 = h*F7([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#     r1 = h*F8([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#     s1 = h*F9([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#     t1 = h*F10([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
    
#     k2 = h*F1([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#     l2 = h*F2([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#     m2 = h*F3([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#     n2 = h*F4([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#     o2 = h*F5([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#     p2 = h*F6([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#     q2 = h*F7([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#     r2 = h*F8([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#     s2 = h*F9([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#     t2 = h*F10([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
    
    
#     k3 = h*F1([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#     l3 = h*F2([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#     m3 = h*F3([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#     n3 = h*F4([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#     o3 = h*F5([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#     p3 = h*F6([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#     q3 = h*F7([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#     r3 = h*F8([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#     s3 = h*F9([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#     t3 = h*F10([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
    
#     y1 = y1+(1/6)*(k0+2*k1+2*k2+k3);
#     y2 = y2+(1/6)*(l0+2*l1+2*l2+l3);
#     y3 = y3+(1/6)*(m0+2*m1+2*m2+m3);
#     y4 = y4+(1/6)*(n0+2*n1+2*n2+n3);
#     y5 = y5+(1/6)*(o0+2*o1+2*o2+o3);
#     y6 = y6+(1/6)*(p0+2*p1+2*p2+p3);
#     y7 = y7+(1/6)*(q0+2*q1+2*q2+q3);
#     y8 = y8+(1/6)*(r0+2*r1+2*r2+r3);
#     y9 = y9+(1/6)*(s0+2*s1+2*s2+s3);
#     y10 = y10+(1/6)*(t0+2*t1+2*t2+t3);
    

#     return y1, y2, y3, y4, y5, y6, y7, y8, y9, y10


# y1 = np.zeros([lt, samples])+0.01
# y2 = np.zeros([lt, samples])+0.01
# y3 = np.zeros([lt, samples])+0.01
# y4 = np.zeros([lt, samples])+0.01
# y5 = np.zeros([lt, samples])+0.01
# y6 = np.zeros([lt, samples])+0.05
# y7 = np.zeros([lt, samples])+0.05
# y8 = np.zeros([lt, samples])+0.05
# y9 = np.zeros([lt, samples])+0.05
# y10 = np.zeros([lt, samples])+0.05

# ft = 20
# am = np.random.uniform(-10, 10, [samples,ft])
# fr = np.random.uniform(0, 10, [samples,ft])
# s1 = np.arange(0,ft,2)
# s2 = np.arange(1,ft,2)
# f = np.zeros([lt, samples])
# for i in range(0, samples):
#     f[:, i] = (np.sum([am[i,j]*np.sin(fr[i,j]*t) for j in s1],0,keepdims=True) +
#                np.sum([am[i,j]*np.cos(fr[i,j]*t) for j in s2],0,keepdims=True))

# M1 = 10; M2 = 10; M3 = 9; M4 = 9; M5 = 7.5; alpha = 100;
# C1 = 100; C2 = 100; C3 = 90; C4 = 90; C5 = 75; 
# K1 = 10000; K2 = 10000; K3 = 9000; K4 = 9000; K5 = 7500; 

# for i in range(0, samples):
#     if i%100 ==  0 or i == samples-1: print('sample number  = ', i) 
#     for j in range(1, lt):
#         y1[j, i], y2[j, i], y3[j, i], y4[j, i], y5[j, i], y6[j, i], y7[j, i], y8[j, i], y9[j, i], y10[j, i] = rkm(y1[j-1, i], y2[j-1, i], y3[j-1, i], y4[j-1, i], y5[j-1, i], y6[j-1, i], y7[j-1, i], y8[j-1, i], y9[j-1, i], y10[j-1, i], f[j-1, i], t[j-1])

# # sp.savemat('data_5DOF_duffing.mat',{'f': f.T, 'y1': y1.T, 'y2': y2.T, 'y3': y3.T, 'y4': y4.T, 'y5': y5.T, 'am': am, 'fr': fr, 't': t, 'dt': dt})
# sp.savemat('data_5DOF_duffing_1500_samples.mat',{'f': f.T, 'y1': y1.T, 'y2': y2.T, 'y3': y3.T, 'y4': y4.T, 'y5': y5.T, 'am': am, 'fr': fr, 't': t, 'dt': dt})

# plt.plot(f[:,0])
# plt.show()        
# plt.plot(y1[:,0])
# plt.show()
# plt.plot(y2[:,0])
# plt.show()
# plt.plot(y3[:,0])
# plt.show()
# plt.plot(y4[:,0])
# plt.show()
# plt.plot(y5[:,0])
# plt.show()
# plt.plot(y6[:,0])
# plt.show()
# plt.plot(y7[:,0])
# plt.show()
# plt.plot(y8[:,0])
# plt.show()
# plt.plot(y9[:,0])
# plt.show()
# plt.plot(y10[:,0])
# plt.show()

# %%
# %reset -f

import time 
import numpy as np
import scipy.io as sp
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Model
from keras.layers.merge import concatenate
from tensorflow.keras import initializers, regularizers
from tensorflow.keras.layers import Dense, Input, Lambda, Dot
from tensorflow.keras.layers.experimental import preprocessing

# def mean_squared_error_outlier(yt, yp):
#     err = np.ravel((yt-yp)**2)
#     err = np.sort(err)[: -len(err) // 1000]
#     return np.mean(err)

with tf.device('/device:cpu:0'):

    dt = 0.01
    min_t = 0
    max_t = 2

    t = np.arange(min_t, max_t, dt)
    lt = t.shape[0]

    training_samples = 500
    mean_sq_error = 0

    data = sp.loadmat('data_5DOF_duffing.mat')
    # data = sp.loadmat('data_5DOF_duffing_1500_samples.mat')
    f = data['f']

    for disp_num in range (0,5):
        if disp_num == 0:
            y = data['y1']
        elif disp_num == 1:
            y = data['y2']
        elif disp_num == 2:
            y = data['y3']
        elif disp_num == 3:
            y = data['y4']
        else:
            y = data['y5']

        train_n = training_samples

        force = f

        pointspsamples = 10
        pointer = np.random.randint(0,lt-1,train_n*pointspsamples)

        UX = np.tile(f[0:train_n,0:-1:2],(pointspsamples,1))
        Y = np.zeros([train_n*pointspsamples,1])
        UXY = np.zeros([train_n*pointspsamples,1])

        for i in range(0,pointspsamples):
            for j in range(0,train_n):
                Y[int(train_n*i+j),0] = t[pointer[train_n*i+j]]
                UXY[int(train_n*i+j),0] = y[j,pointer[train_n*i+j]]

        ux_sensors = 100
        y_sensors = 1


        # # # # # # # # # # # # # # # # # # # #    

        def layer_dense(nodes = 1, activation_func = 'relu',
                        kernel_init = initializers.GlorotNormal(),
                        name = None):
            layer = Dense(nodes, activation = activation_func,
                         kernel_initializer = kernel_init,
                         name = name)
            return layer

        def fn(x):
            y = tf.einsum("ij,ij->i", x[0], x[1])
            y = tf.expand_dims(y, axis=1)
            return y

        hidden_layer_nodes = 40

        layer_input_a = Input(shape = (ux_sensors, ), name = "input_a")    
        normalizer_a = preprocessing.Normalization(input_shape = [ux_sensors, ], name = '15_a')
        normalizer_a.adapt(UX)
        layer_15_a = normalizer_a(layer_input_a)
        layer_20_a = layer_dense(hidden_layer_nodes, name = '20_a')(layer_15_a)
        layer_25_a = layer_dense(hidden_layer_nodes, name = '25_a')(layer_20_a)

        layer_input_b = Input(shape = (y_sensors, ), name = "input_b")
        normalizer_b = preprocessing.Normalization(input_shape = [y_sensors, ], name = '15_b')
        normalizer_b.adapt(Y)
        layer_15_b = normalizer_b(layer_input_b)    
        layer_20_b = layer_dense(hidden_layer_nodes, name = '20_b')(layer_15_b)
        layer_25_b = layer_dense(hidden_layer_nodes, name = '25_b')(layer_20_b)

        layer_35 = Lambda(fn, output_shape = [None,1], name = '35')([layer_25_a, layer_25_b])
        layer_40 = Dense(1, activation = None,
                         kernel_initializer = initializers.GlorotNormal(),
                         name = '40')(layer_35)

        model = Model(inputs = [layer_input_a, layer_input_b], outputs = layer_40)
        model.summary()

        model.compile(loss = 'mse',
                      optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
                      metrics = 'mae')

        train_dataset = tf.data.Dataset.from_tensor_slices(({"input_a":UX, "input_b":Y}, UXY)).batch(128)

        start_time = time.time()
        for i in range(0,20):
            print('iteration = '+str(i))
            model.fit(train_dataset,
                      epochs = 1, verbose = 1, batch_size = 128)
            model.fit(train_dataset,
                      epochs = 499, verbose = 0, batch_size = 128)
        print('Time(s) --> ',time.time()-start_time)

    #     from numpy.ma import MaskedArray
    #     import sklearn.utils.fixes
    #     sklearn.utils.fixes.MaskedArray = MaskedArray
    #     import deepxde as dde

    #     data_NN = dde.data.triple.Triple((UX, Y), UXY, (UX[-500:-1,:], Y[-500:-1,:]), UXY[-500:-1,:])
    #     nn = dde.nn.tensorflow_compat_v1.DeepONet(
    #         [100, 40, 40],
    #         [1, 40, 40],
    #         'relu',
    #         'Glorot normal',
    #         use_bias = True,
    #         stacked = False)

    #     model = dde.model.Model(data_NN, nn)
    #     model.compile('adam', lr = 0.001, metrics = [mean_squared_error_outlier])
    #     model.train(epochs = 10000)

        string = '10PPS_model_save_5DOF_nonlinear_'+str(train_n)+'_displacement_'+str(disp_num+1)
        model.save(string)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_a (InputLayer)           [(None, 100)]        0           []
#
#  input_b (InputLayer)           [(None, 1)]          0           []
#
#  15_a (Normalization)           (None, 100)          201         ['input_a[0][0]']
#
#  15_b (Normalization)           (None, 1)            3           ['input_b[0][0]']
#
#  20_a (Dense)                   (None, 40)           4040        ['15_a[0][0]']
#
#  20_b (Dense)                   (None, 40)           80          ['15_b[0][0]']
#
#  25_a (Dense)                   (None, 40)           1640        ['20_a[0][0]']
#
#  25_b (Dense)                   (None, 40)           1640        ['20_b[0][0]']
#
#  35 (Lambda)                    (None, 1)            0           ['25_a[0][0]',
#                                                                   '25_b[0][0]']
#
#  40 (Dense)                     (None, 1)            2           ['35[0][0]']
#
# ==================================================================================================
# Total params: 7,606
# Trainable params: 7,402
# Non-trainable params: 204
# __________________________________________________________________________________________________
# iteration = 0
# 40/40 [==============================] - 0s 1ms/step - loss: 0.3402 - mae: 0.3135
# iteration = 1
# 40/40 [==============================] - 0s 1ms/step - loss: 3.1657e-04 - mae: 0.0137
# iteration = 2
# 40/40 [==============================] - 0s 1ms/step - loss: 1.1572e-04 - mae: 0.0083
# iteration = 3
# 40/40 [==============================] - 0s 1ms/step - loss: 1.0498e-04 - mae: 0.0078
# iteration = 4
# 40/40 [==============================] - 0s 1ms/step - loss: 1.2497e-04 - mae: 0.0087
# iteration = 5
# 40/40 [==============================] - 0s 1ms/step - loss: 5.7562e-05 - mae: 0.0057
# iteration = 6
# 40/40 [==============================] - 0s 1ms/step - loss: 9.5347e-05 - mae: 0.0073
# iteration = 7
# 40/40 [==============================] - 0s 1ms/step - loss: 5.7896e-05 - mae: 0.0059
# iteration = 8
# 40/40 [==============================] - 0s 1ms/step - loss: 5.3379e-05 - mae: 0.0056
# iteration = 9
# 40/40 [==============================] - 0s 1ms/step - loss: 3.5971e-05 - mae: 0.0045
# iteration = 10
# 40/40 [==============================] - 0s 1ms/step - loss: 4.8609e-05 - mae: 0.0053
# iteration = 11
# 40/40 [==============================] - 0s 1ms/step - loss: 5.0959e-05 - mae: 0.0054
# iteration = 12
# 40/40 [==============================] - 0s 1ms/step - loss: 4.0785e-05 - mae: 0.0048
# iteration = 13
# 40/40 [==============================] - 0s 1ms/step - loss: 4.0823e-05 - mae: 0.0049
# iteration = 14
# 40/40 [==============================] - 0s 968us/step - loss: 3.5482e-05 - mae: 0.0045
# iteration = 15
# 40/40 [==============================] - 0s 968us/step - loss: 2.9812e-05 - mae: 0.0042
# iteration = 16
# 40/40 [==============================] - 0s 801us/step - loss: 3.3294e-05 - mae: 0.0044
# iteration = 17
# 40/40 [==============================] - 0s 801us/step - loss: 3.0932e-05 - mae: 0.0042
# iteration = 18
# 40/40 [==============================] - 0s 1ms/step - loss: 8.3748e-05 - mae: 0.0068
# iteration = 19
# 40/40 [==============================] - 0s 968us/step - loss: 5.8318e-05 - mae: 0.0057
# Time(s) -->  400.56386160850525
# INFO:tensorflow:Assets written to: 10PPS_model_save_5DOF_nonlinear_500_displacement_1\assets
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_a (InputLayer)           [(None, 100)]        0           []
#
#  input_b (InputLayer)           [(None, 1)]          0           []
#
#  15_a (Normalization)           (None, 100)          201         ['input_a[0][0]']
#
#  15_b (Normalization)           (None, 1)            3           ['input_b[0][0]']
#
#  20_a (Dense)                   (None, 40)           4040        ['15_a[0][0]']
#
#  20_b (Dense)                   (None, 40)           80          ['15_b[0][0]']
#
#  25_a (Dense)                   (None, 40)           1640        ['20_a[0][0]']
#
#  25_b (Dense)                   (None, 40)           1640        ['20_b[0][0]']
#
#  35 (Lambda)                    (None, 1)            0           ['25_a[0][0]',
#                                                                   '25_b[0][0]']
#
#  40 (Dense)                     (None, 1)            2           ['35[0][0]']
#
# ==================================================================================================
# Total params: 7,606
# Trainable params: 7,402
# Non-trainable params: 204
# __________________________________________________________________________________________________
# iteration = 0
# 40/40 [==============================] - 0s 863us/step - loss: 0.1108 - mae: 0.2437
# iteration = 1
# 40/40 [==============================] - 0s 801us/step - loss: 3.0987e-04 - mae: 0.0135
# iteration = 2
# 40/40 [==============================] - 0s 801us/step - loss: 2.4490e-04 - mae: 0.0120
# iteration = 3
# 40/40 [==============================] - 0s 801us/step - loss: 2.5683e-04 - mae: 0.0123
# iteration = 4
# 40/40 [==============================] - 0s 968us/step - loss: 2.0513e-04 - mae: 0.0109
# iteration = 5
# 40/40 [==============================] - 0s 968us/step - loss: 2.2744e-04 - mae: 0.0118
# iteration = 6
# 40/40 [==============================] - 0s 968us/step - loss: 1.3353e-04 - mae: 0.0088
# iteration = 7
# 40/40 [==============================] - 0s 968us/step - loss: 1.3541e-04 - mae: 0.0089
# iteration = 8
# 40/40 [==============================] - 0s 801us/step - loss: 1.1064e-04 - mae: 0.0081
# iteration = 9
# 40/40 [==============================] - 0s 968us/step - loss: 1.6447e-04 - mae: 0.0099
# iteration = 10
# 40/40 [==============================] - 0s 801us/step - loss: 1.6104e-04 - mae: 0.0098
# iteration = 11
# 40/40 [==============================] - 0s 801us/step - loss: 2.1361e-04 - mae: 0.0111
# iteration = 12
# 40/40 [==============================] - 0s 1ms/step - loss: 1.6565e-04 - mae: 0.0100
# iteration = 13
# 40/40 [==============================] - 0s 968us/step - loss: 9.9553e-05 - mae: 0.0076
# iteration = 14
# 40/40 [==============================] - 0s 801us/step - loss: 9.1530e-05 - mae: 0.0072
# iteration = 15
# 40/40 [==============================] - 0s 1ms/step - loss: 2.1863e-04 - mae: 0.0114
# iteration = 16
# 40/40 [==============================] - 0s 968us/step - loss: 9.6085e-05 - mae: 0.0075
# iteration = 17
# 40/40 [==============================] - 0s 968us/step - loss: 1.3151e-04 - mae: 0.0088
# iteration = 18
# 40/40 [==============================] - 0s 968us/step - loss: 9.6797e-05 - mae: 0.0074
# iteration = 19
# 40/40 [==============================] - 0s 801us/step - loss: 1.7148e-04 - mae: 0.0099
# Time(s) -->  397.7452566623688
# INFO:tensorflow:Assets written to: 10PPS_model_save_5DOF_nonlinear_500_displacement_2\assets
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_a (InputLayer)           [(None, 100)]        0           []
#
#  input_b (InputLayer)           [(None, 1)]          0           []
#
#  15_a (Normalization)           (None, 100)          201         ['input_a[0][0]']
#
#  15_b (Normalization)           (None, 1)            3           ['input_b[0][0]']
#
#  20_a (Dense)                   (None, 40)           4040        ['15_a[0][0]']
#
#  20_b (Dense)                   (None, 40)           80          ['15_b[0][0]']
#
#  25_a (Dense)                   (None, 40)           1640        ['20_a[0][0]']
#
#  25_b (Dense)                   (None, 40)           1640        ['20_b[0][0]']
#
#  35 (Lambda)                    (None, 1)            0           ['25_a[0][0]',
#                                                                   '25_b[0][0]']
#
#  40 (Dense)                     (None, 1)            2           ['35[0][0]']
#
# ==================================================================================================
# Total params: 7,606
# Trainable params: 7,402
# Non-trainable params: 204
# __________________________________________________________________________________________________
# iteration = 0
# 40/40 [==============================] - 0s 659us/step - loss: 0.2862 - mae: 0.3957
# iteration = 1
# 40/40 [==============================] - 0s 968us/step - loss: 7.0647e-04 - mae: 0.0202
# iteration = 2
# 40/40 [==============================] - 0s 968us/step - loss: 5.2426e-04 - mae: 0.0174
# iteration = 3
# 40/40 [==============================] - 0s 801us/step - loss: 5.0200e-04 - mae: 0.0171
# iteration = 4
# 40/40 [==============================] - 0s 1ms/step - loss: 2.4516e-04 - mae: 0.0121
# iteration = 5
# 40/40 [==============================] - 0s 801us/step - loss: 5.8789e-04 - mae: 0.0185
# iteration = 6
# 40/40 [==============================] - 0s 968us/step - loss: 2.6208e-04 - mae: 0.0126
# iteration = 7
# 40/40 [==============================] - 0s 968us/step - loss: 2.5390e-04 - mae: 0.0123
# iteration = 8
# 40/40 [==============================] - 0s 801us/step - loss: 2.3902e-04 - mae: 0.0119
# iteration = 9
# 40/40 [==============================] - 0s 968us/step - loss: 2.2160e-04 - mae: 0.0115
# iteration = 10
# 40/40 [==============================] - 0s 801us/step - loss: 2.3867e-04 - mae: 0.0118
# iteration = 11
# 40/40 [==============================] - 0s 801us/step - loss: 1.3298e-04 - mae: 0.0087
# iteration = 12
# 40/40 [==============================] - 0s 968us/step - loss: 1.7892e-04 - mae: 0.0103
# iteration = 13
# 40/40 [==============================] - 0s 1ms/step - loss: 4.4868e-04 - mae: 0.0159
# iteration = 14
# 40/40 [==============================] - 0s 801us/step - loss: 1.1811e-04 - mae: 0.0084
# iteration = 15
# 40/40 [==============================] - 0s 968us/step - loss: 2.5338e-04 - mae: 0.0124
# iteration = 16
# 40/40 [==============================] - 0s 968us/step - loss: 3.2665e-04 - mae: 0.0142
# iteration = 17
# 40/40 [==============================] - 0s 968us/step - loss: 1.3497e-04 - mae: 0.0090
# iteration = 18
# 40/40 [==============================] - 0s 801us/step - loss: 2.1811e-04 - mae: 0.0113
# iteration = 19
# 40/40 [==============================] - 0s 968us/step - loss: 1.7278e-04 - mae: 0.0101
# Time(s) -->  398.21061539649963
# INFO:tensorflow:Assets written to: 10PPS_model_save_5DOF_nonlinear_500_displacement_3\assets
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_a (InputLayer)           [(None, 100)]        0           []
#
#  input_b (InputLayer)           [(None, 1)]          0           []
#
#  15_a (Normalization)           (None, 100)          201         ['input_a[0][0]']
#
#  15_b (Normalization)           (None, 1)            3           ['input_b[0][0]']
#
#  20_a (Dense)                   (None, 40)           4040        ['15_a[0][0]']
#
#  20_b (Dense)                   (None, 40)           80          ['15_b[0][0]']
#
#  25_a (Dense)                   (None, 40)           1640        ['20_a[0][0]']
#
#  25_b (Dense)                   (None, 40)           1640        ['20_b[0][0]']
#
#  35 (Lambda)                    (None, 1)            0           ['25_a[0][0]',
#                                                                   '25_b[0][0]']
#
#  40 (Dense)                     (None, 1)            2           ['35[0][0]']
#
# ==================================================================================================
# Total params: 7,606
# Trainable params: 7,402
# Non-trainable params: 204
# __________________________________________________________________________________________________
# iteration = 0
# 40/40 [==============================] - 0s 863us/step - loss: 0.3725 - mae: 0.4617
# iteration = 1
# 40/40 [==============================] - 0s 801us/step - loss: 0.0021 - mae: 0.0325
# iteration = 2
# 40/40 [==============================] - 0s 1ms/step - loss: 0.0016 - mae: 0.0303
# iteration = 3
# 40/40 [==============================] - 0s 801us/step - loss: 8.6951e-04 - mae: 0.0220
# iteration = 4
# 40/40 [==============================] - 0s 968us/step - loss: 9.0668e-04 - mae: 0.0227
# iteration = 5
# 40/40 [==============================] - 0s 1ms/step - loss: 5.4103e-04 - mae: 0.0172
# iteration = 6
# 40/40 [==============================] - 0s 801us/step - loss: 7.4564e-04 - mae: 0.0203
# iteration = 7
# 40/40 [==============================] - 0s 801us/step - loss: 3.8040e-04 - mae: 0.0146
# iteration = 8
# 40/40 [==============================] - 0s 801us/step - loss: 4.0890e-04 - mae: 0.0153
# iteration = 9
# 40/40 [==============================] - 0s 968us/step - loss: 4.2537e-04 - mae: 0.0156
# iteration = 10
# 40/40 [==============================] - 0s 1ms/step - loss: 3.8826e-04 - mae: 0.0145
# iteration = 11
# 40/40 [==============================] - 0s 1ms/step - loss: 3.4073e-04 - mae: 0.0140
# iteration = 12
# 40/40 [==============================] - 0s 801us/step - loss: 3.5959e-04 - mae: 0.0143
# iteration = 13
# 40/40 [==============================] - 0s 801us/step - loss: 4.1448e-04 - mae: 0.0153
# iteration = 14
# 40/40 [==============================] - 0s 968us/step - loss: 3.9571e-04 - mae: 0.0149
# iteration = 15
# 40/40 [==============================] - 0s 801us/step - loss: 4.3517e-04 - mae: 0.0160
# iteration = 16
# 40/40 [==============================] - 0s 801us/step - loss: 2.9872e-04 - mae: 0.0132
# iteration = 17
# 40/40 [==============================] - 0s 1ms/step - loss: 3.1171e-04 - mae: 0.0129
# iteration = 18
# 40/40 [==============================] - 0s 801us/step - loss: 5.4720e-04 - mae: 0.0173
# iteration = 19
# 40/40 [==============================] - 0s 968us/step - loss: 2.4618e-04 - mae: 0.0120
# Time(s) -->  394.7238473892212
# INFO:tensorflow:Assets written to: 10PPS_model_save_5DOF_nonlinear_500_displacement_4\assets
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_a (InputLayer)           [(None, 100)]        0           []
#
#  input_b (InputLayer)           [(None, 1)]          0           []
#
#  15_a (Normalization)           (None, 100)          201         ['input_a[0][0]']
#
#  15_b (Normalization)           (None, 1)            3           ['input_b[0][0]']
#
#  20_a (Dense)                   (None, 40)           4040        ['15_a[0][0]']
#
#  20_b (Dense)                   (None, 40)           80          ['15_b[0][0]']
#
#  25_a (Dense)                   (None, 40)           1640        ['20_a[0][0]']
#
#  25_b (Dense)                   (None, 40)           1640        ['20_b[0][0]']
#
#  35 (Lambda)                    (None, 1)            0           ['25_a[0][0]',
#                                                                   '25_b[0][0]']
#
#  40 (Dense)                     (None, 1)            2           ['35[0][0]']
#
# ==================================================================================================
# Total params: 7,606
# Trainable params: 7,402
# Non-trainable params: 204
# __________________________________________________________________________________________________
# iteration = 0
# 40/40 [==============================] - 0s 863us/step - loss: 0.4154 - mae: 0.4901
# iteration = 1
# 40/40 [==============================] - 0s 801us/step - loss: 0.0018 - mae: 0.0313
# iteration = 2
# 40/40 [==============================] - 0s 968us/step - loss: 0.0015 - mae: 0.0288
# iteration = 3
# 40/40 [==============================] - 0s 1ms/step - loss: 0.0010 - mae: 0.0240
# iteration = 4
# 40/40 [==============================] - 0s 801us/step - loss: 0.0011 - mae: 0.0249
# iteration = 5
# 40/40 [==============================] - 0s 1ms/step - loss: 8.9597e-04 - mae: 0.0226
# iteration = 6
# 40/40 [==============================] - 0s 1ms/step - loss: 9.0266e-04 - mae: 0.0228
# iteration = 7
# 40/40 [==============================] - 0s 801us/step - loss: 0.0013 - mae: 0.0273
# iteration = 8
# 40/40 [==============================] - 0s 1ms/step - loss: 5.7740e-04 - mae: 0.0184
# iteration = 9
# 40/40 [==============================] - 0s 1ms/step - loss: 6.3615e-04 - mae: 0.0191
# iteration = 10
# 40/40 [==============================] - 0s 1ms/step - loss: 5.8696e-04 - mae: 0.0185
# iteration = 11
# 40/40 [==============================] - 0s 968us/step - loss: 5.4878e-04 - mae: 0.0180
# iteration = 12
# 40/40 [==============================] - 0s 968us/step - loss: 7.2530e-04 - mae: 0.0206
# iteration = 13
# 40/40 [==============================] - 0s 801us/step - loss: 4.8410e-04 - mae: 0.0168
# iteration = 14
# 40/40 [==============================] - 0s 801us/step - loss: 7.4111e-04 - mae: 0.0211
# iteration = 15
# 40/40 [==============================] - 0s 801us/step - loss: 4.4017e-04 - mae: 0.0161
# iteration = 16
# 40/40 [==============================] - 0s 968us/step - loss: 6.3234e-04 - mae: 0.0195
# iteration = 17
# 40/40 [==============================] - 0s 1ms/step - loss: 3.9009e-04 - mae: 0.0151
# iteration = 18
# 40/40 [==============================] - 0s 1ms/step - loss: 5.3313e-04 - mae: 0.0180
# iteration = 19
# 40/40 [==============================] - 0s 801us/step - loss: 4.8173e-04 - mae: 0.0169
# Time(s) -->  410.49225783348083
# INFO:tensorflow:Assets written to: 10PPS_model_save_5DOF_nonlinear_500_displacement_5\assets

# %%
# %reset -f

import numpy as np
import scipy.io as sp
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Model
from keras.layers.merge import concatenate
from tensorflow.keras import initializers, regularizers
from tensorflow.keras.layers import Dense, Input, Lambda, Dot
from tensorflow.keras.layers.experimental import preprocessing

with tf.device('/device:cpu:0'):
    dt = 0.01
    min_t = 0
    max_t = 2

    t = np.arange(min_t, max_t, dt)
    lt = t.shape[0]

    test_samples = 10000
    
    predicted = np.zeros([10000,200])
    x_test_0_new = np.zeros([2000000, 100])
    x_test_1_new = np.zeros([2000000, 1])

#     def rkm(y1, y2, y3, y4, y5, y6, y7, y8, y9, y10, f, t):
#         h = dt

#         F1 = lambda Y: Y[6]
#         F2 = lambda Y: Y[7]
#         F3 = lambda Y: Y[8]
#         F4 = lambda Y: Y[9]
#         F5 = lambda Y: Y[10]
#         F6 = lambda Y: (1/M1)*(-M1*f-(C1*Y[5+1]+K1*Y[1]+C2*(Y[5+1]-Y[5+2])+K2*(Y[1]-Y[2])+alpha*Y[1]**3))
#         F7 = lambda Y: (1/M2)*(-M2*f-(C2*(Y[5+2]-Y[5+1])+K2*(Y[2]-Y[1])+C3*(Y[5+2]-Y[5+3])+K3*(Y[2]-Y[3])))
#         F8 = lambda Y: (1/M3)*(-M3*f-(C3*(Y[5+3]-Y[5+2])+K3*(Y[3]-Y[2])+C4*(Y[5+3]-Y[5+4])+K5*(Y[3]-Y[4])))
#         F9 = lambda Y: (1/M4)*(-M4*f-(C4*(Y[5+4]-Y[5+3])+K4*(Y[4]-Y[3])+C5*(Y[5+4]-Y[5+5])+K5*(Y[4]-Y[5])))
#         F10 = lambda Y: (1/M5)*(-M5*f-(C5*(Y[5+5]-Y[5+4])+K5*(Y[5]-Y[4])))


#         k0 = h*F1([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#         l0 = h*F2([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#         m0 = h*F3([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#         n0 = h*F4([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#         o0 = h*F5([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#         p0 = h*F6([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#         q0 = h*F7([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#         r0 = h*F8([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#         s0 = h*F9([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);
#         t0 = h*F10([t, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10]);

#         k1 = h*F1([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#         l1 = h*F2([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#         m1 = h*F3([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#         n1 = h*F4([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#         o1 = h*F5([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#         p1 = h*F6([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#         q1 = h*F7([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#         r1 = h*F8([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#         s1 = h*F9([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);
#         t1 = h*F10([t+0.5*h, y1+0.5*k0, y2+0.5*l0, y3+0.5*m0, y4+0.5*n0, y5+0.5*o0, y6+0.5*p0, y7+0.5*q0, y8+0.5*r0, y9+0.5*s0, y10+0.5*t0]);

#         k2 = h*F1([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#         l2 = h*F2([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#         m2 = h*F3([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#         n2 = h*F4([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#         o2 = h*F5([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#         p2 = h*F6([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#         q2 = h*F7([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#         r2 = h*F8([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#         s2 = h*F9([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);
#         t2 = h*F10([t+0.5*h, y1+0.5*k1, y2+0.5*l1, y3+0.5*m1, y4+0.5*n1, y5+0.5*o1, y6+0.5*p1, y7+0.5*q1, y8+0.5*r1, y9+0.5*s1, y10+0.5*t1]);


#         k3 = h*F1([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#         l3 = h*F2([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#         m3 = h*F3([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#         n3 = h*F4([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#         o3 = h*F5([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#         p3 = h*F6([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#         q3 = h*F7([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#         r3 = h*F8([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#         s3 = h*F9([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);
#         t3 = h*F10([t+h, y1+k2, y2+l2, y3+m2, y4+n2, y5+o2, y6+p2, y7+q2, y8+r2, y9+s2, y10+t2]);

#         y1 = y1+(1/6)*(k0+2*k1+2*k2+k3);
#         y2 = y2+(1/6)*(l0+2*l1+2*l2+l3);
#         y3 = y3+(1/6)*(m0+2*m1+2*m2+m3);
#         y4 = y4+(1/6)*(n0+2*n1+2*n2+n3);
#         y5 = y5+(1/6)*(o0+2*o1+2*o2+o3);
#         y6 = y6+(1/6)*(p0+2*p1+2*p2+p3);
#         y7 = y7+(1/6)*(q0+2*q1+2*q2+q3);
#         y8 = y8+(1/6)*(r0+2*r1+2*r2+r3);
#         y9 = y9+(1/6)*(s0+2*s1+2*s2+s3);
#         y10 = y10+(1/6)*(t0+2*t1+2*t2+t3);


#         return y1, y2, y3, y4, y5, y6, y7, y8, y9, y10

    ft_terms = [20, 25, 50, 75, 100]

    for num in range(0,5):

        y1 = np.zeros([lt, test_samples])+0.01
        y2 = np.zeros([lt, test_samples])+0.01
        y3 = np.zeros([lt, test_samples])+0.01
        y4 = np.zeros([lt, test_samples])+0.01
        y5 = np.zeros([lt, test_samples])+0.01
        y6 = np.zeros([lt, test_samples])+0.05
        y7 = np.zeros([lt, test_samples])+0.05
        y8 = np.zeros([lt, test_samples])+0.05
        y9 = np.zeros([lt, test_samples])+0.05
        y10 = np.zeros([lt, test_samples])+0.05

        ft = ft_terms[num]
        # am = np.random.uniform(-10, 10, [test_samples,ft])
        # fr = np.random.uniform(0, 10, [test_samples,ft])
        # s1 = np.arange(0,ft,2)
        # s2 = np.arange(1,ft,2)
        # f = np.zeros([lt, test_samples])
        # for i in range(0, test_samples):
        #     f[:, i] = (np.sum([am[i,j]*np.sin(fr[i,j]*t) for j in s1],0,keepdims=True) +
        #                np.sum([am[i,j]*np.cos(fr[i,j]*t) for j in s2],0,keepdims=True))

#         M1 = 10; M2 = 10; M3 = 9; M4 = 9; M5 = 7.5; alpha = 100;
#         C1 = 100; C2 = 100; C3 = 90; C4 = 90; C5 = 75; 
#         K1 = 10000; K2 = 10000; K3 = 9000; K4 = 9000; K5 = 7500; 

#         for i in range(0, test_samples):
#             if i%1000 ==  0 or i == test_samples-1: print('sample number  = ', i) 
#             for j in range(1, lt):
#                 y1[j, i], y2[j, i], y3[j, i], y4[j, i], y5[j, i], y6[j, i], y7[j, i], y8[j, i], y9[j, i], y10[j, i] = rkm(y1[j-1, i], y2[j-1, i], y3[j-1, i], y4[j-1, i], y5[j-1, i], y6[j-1, i], y7[j-1, i], y8[j-1, i], y9[j-1, i], y10[j-1, i], f[j-1, i], t[j-1])

        string = '5DOF_DO_testing_data_FT_'+str(ft)+'.mat'
#         sp.savemat(string,{'force': f, 'y1': y1, 'y2': y2, 'y3': y3, 'y4': y4, 'y5': y5, 'fourier_terms': ft})

        test_data = sp.loadmat(string)
        f = test_data['force']
        y1 = test_data['y1']
        y2 = test_data['y2']
        y3 = test_data['y3']
        y4 = test_data['y4']
        y5 = test_data['y5']
        
        
        x_test = f[0:-1:2,:].T

        training_samples = [500] # [1500]

        for disp_num in range(0,5):
            if disp_num == 0:
                y = y1.T
            elif disp_num == 1:
                y = y2.T
            elif disp_num == 2:
                y = y3.T
            elif disp_num == 3:
                y = y4.T
            else:
                y = y5.T

            for model_num in range(0,1):

                string = '10PPS_model_save_5DOF_nonlinear_'+str(training_samples[model_num])+'_displacement_'+str(disp_num+1)
                model = tf.keras.models.load_model(string)
                print('5DOF_nonlinear_'+str(training_samples[model_num])+'_displacement_'+str(disp_num+1))
                
                for i in range(0,test_samples):
                    x_test_0_new[lt*i:lt+lt*i,:] = np.tile(x_test[i,:],[200,1])
                    x_test_1_new[lt*i:lt+lt*i,:] = t.reshape([lt,1])
                
                predictions_new = model({"input_a":x_test_0_new, "input_b":x_test_1_new})
                predictions_new = np.array(predictions_new)
                
                for i in range(0,test_samples):
                    predicted[i,:] = predictions_new[lt*i:lt+lt*i].reshape(1,-1)
                    
                string = '10PPS_5DOF_DO_training_samples_'+str(training_samples[model_num])+'_displacement_'+str(disp_num+1)+'_FT_'+str(ft)+'.mat' 
                sp.savemat(string,{'actual_y': y, 'predicted_y': predicted, 'model_num': training_samples[model_num],
                                                    'disp_num': disp_num+1, 'fourier_terms': ft})
# Out:
# 5DOF_nonlinear_500_displacement_1
# 5DOF_nonlinear_500_displacement_2
# 5DOF_nonlinear_500_displacement_3
# 5DOF_nonlinear_500_displacement_4
# 5DOF_nonlinear_500_displacement_5
# 5DOF_nonlinear_500_displacement_1
# 5DOF_nonlinear_500_displacement_2
# 5DOF_nonlinear_500_displacement_3
# 5DOF_nonlinear_500_displacement_4
# 5DOF_nonlinear_500_displacement_5
# 5DOF_nonlinear_500_displacement_1
# 5DOF_nonlinear_500_displacement_2
# 5DOF_nonlinear_500_displacement_3
# 5DOF_nonlinear_500_displacement_4
# 5DOF_nonlinear_500_displacement_5
# 5DOF_nonlinear_500_displacement_1
# 5DOF_nonlinear_500_displacement_2
# 5DOF_nonlinear_500_displacement_3
# 5DOF_nonlinear_500_displacement_4
# 5DOF_nonlinear_500_displacement_5
# 5DOF_nonlinear_500_displacement_1
# 5DOF_nonlinear_500_displacement_2
# 5DOF_nonlinear_500_displacement_3
# 5DOF_nonlinear_500_displacement_4
# 5DOF_nonlinear_500_displacement_5
